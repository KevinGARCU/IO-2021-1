# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinGARCU/IO-2021-1/blob/main/Metodo_de_la_gran_M.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2021-05-02 at 4.20.55 PM.jpeg](data:image/jpeg;base64,...)

# %%
import numpy as np
from scipy import optimize as op

 # Dar el rango de valores de la variable
x1=(0,None)
x2=(0,None)
x3=(0,None)

c = np.array ([2,1,1]) # Coeficiente de función objetivo, vector de columna 3x1
A_ub = np.array ([[0,-2, 1], [0,1, -1]]) # Coeficiente de restricción de desigualdad A, matriz de 2x3 dimensiones
B_ub = np.array ([- 2,1]) # Coeficiente de restricción de desigualdad B, vector de columna dimensional 2x1
A_eq = np.array ([[1, -1,1]]) # Coeficiente de restricción de igualdad Aeq, vector de columna dimensional 3x1
B_eq = np.array ([2]) # coeficiente de restricción de ecuación beq, valor 1x1
res = op.linprog (c, A_ub, B_ub, A_eq, B_eq) # Función de llamada para resolver
#op.linprog()
res
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      con: array([1.15198961e-11])
#      fun: 6.999999999952099
#  message: 'Optimization terminated successfully.'
#      nit: 4
#    slack: array([-1.66473502e-11,  8.43292103e-12])
#   status: 0
#  success: True
#        x: array([3.0000000e+00, 1.0000000e+00, 2.1860308e-13])
